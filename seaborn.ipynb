# %%
import seaborn as sb

# %% [markdown]
# ## Basic Plotting with seaborn

# %%
tips=sb.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## create a scatter plot
import matplotlib.pyplot as plt
sb.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("Scatter Plot of total Bill Vs Tip")
plt.show()

# %%
## Line Plot
sb.lineplot(x='size',y='total_bill', data=tips)
plt.title("Total bill by size")
plt.show()

# %%
## Categorical Plots
## Bar Plots
sb.barplot(x='day',y='total_bill',data=tips)
plt.title("Bar Plot total bills according to the day")
# Out:
# Text(0.5, 1.0, 'Bar Plot total bills according to the day')

# %%
## Box Plot
sb.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## volin plot
sb.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## Histograms
sb.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE
sb.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## Pairplot
sb.pairplot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## heatmap
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sb.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
sales_df=pd.read_csv("sales_data.csv")

# %%
plt.figure(figsize=(10,6))
sb.barplot(x='Product Category',y='Total Revenue',data=sales_df,estimator=sum)
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Revenue'>

# %%
plt.figure(figsize=(10,6))
sb.barplot(x='Region',y='Total Revenue',data=sales_df,estimator=sum)
plt.xlabel('Rgion')
# Out:
# <Axes: xlabel='Region', ylabel='Total Revenue'>
